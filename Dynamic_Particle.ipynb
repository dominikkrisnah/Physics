# %% [markdown]
# By: Dominikus Krisna Herlambang | 2022

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
t = np.linspace(0,15,1000)
omega_sq = 1
y = [0,2]

# %%
def harmonic(t,y):
    solution = [y[1],-omega_sq*y[0]]
    return solution
krisna = solve_ivp(harmonic, [0,1000], y0 = y, t_eval = t)

# %%
plt.figure(num=None, figsize=(15,6))
plt.plot(t,krisna.y[0],color='maroon')
plt.ylabel("Position (m)", fontsize = 18)
plt.xlabel("Time (s)",fontsize = 18)
plt.title('Position-Time Graphs', fontsize = 24)
# Out:
# Text(0.5, 1.0, 'Position-Time Graphs')

# %%
t = np.linspace(0,15,1000)
y = [0,1]
gamma = 1
omega_sqr = 100
def dominik(t,y):
    solution = (y[1],(-gamma*y[1]-omega_sqr*y[0]))
    return solution
solution = solve_ivp(dominik, [0,1000], y0 = y, t_eval = t)

# %%
plt.figure(num=None, figsize=(15,6))
plt.plot(t,solution.y[0],color='darkgreen')
plt.ylabel("Speed (m/s)",fontsize = 18)
plt.xlabel("Time (s)",fontsize = 18)
plt.title('Speed-Time graphs', fontsize = 24)
# Out:
# Text(0.5, 1.0, 'Speed-Time graphs')

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time (s)')
ax1.set_ylabel("Position (m)", color=color)
ax1.plot(t, krisna.y[0], color=color)

ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Speed(m/s)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, solution.y[0], color=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
